# %% [markdown]
# # Making this event happen
#
# We were only able to build this event for you by re-using a lot of existing tools and services.

# %%
    
    import graphviz, pathlib, base64, graphviz2drawio.graphviz2drawio as d2g
    dot = pathlib.Path("env.dot").read_text()
    b64 = base64.b64encode(
        graphviz.Source(dot)._repr_svg_().encode("utf-8")
    ).decode("utf-8")

# %%
<img src="data:image/svg+xml;base64,{{b64}}"/>
# Out:
# <img src="data:image/svg+xml;base64,..."/>
